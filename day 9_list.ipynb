# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhantx21/python-practice/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,23,44,3,53,323,1]
l.append(2)
print(l)
l.sort()
print(l)
l.sort(reverse=True)
print(l)
print(l.index(1))
print(l.count(1))
# Out:
# [1, 23, 44, 3, 53, 323, 1, 2]
# [1, 1, 2, 3, 23, 44, 53, 323]
# [323, 53, 44, 23, 3, 2, 1, 1]
# 6
# 2

# %%
l=[1,23,44,3,53,323,1]
m=l
m[0]=0
print(l)
m=l.copy()
m[0]=3
print(l)
print(m)
l.insert(1,22)
print(l)
n=[1,23,242,4,23]
l.extend(m)
print(l)
# Out:
# [0, 23, 44, 3, 53, 323, 1]
# [0, 23, 44, 3, 53, 323, 1]
# [3, 23, 44, 3, 53, 323, 1]
# [0, 22, 23, 44, 3, 53, 323, 1]
# [0, 22, 23, 44, 3, 53, 323, 1, 3, 23, 44, 3, 53, 323, 1]

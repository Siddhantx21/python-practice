# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhantx21/python-practice/blob/main/day7_fucntionbasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def OddorEven(a):
  if(a%2==0):
    print("The number is even")
  else:
    print("The number is odd")
a=float(input("Enter the value of a:"))
OddorEven(a)
# Out:
# Enter the value of a:2
# The number is even

# %%
def GreaterorSmaller(a,b):
  if(a>b):
    print("a is greater than b")
  elif(a<b):
    print("a is smaller than b")
  else:
    print("a is equal to b")

a=float(input("Enter the value of a:"))
b=float(input("Enter the value of b:"))
GreaterorSmaller(a,b)
# Out:
# Enter the value of a:23
# Enter the value of b:1
# a is greater than b

# %%
def primeno(n):
    if n <= 1:
        print("Not a prime no.")
    elif n==2:
      print("Prime no.")
    else:
        for i in range(2, n):
            if (n % i == 0):
                print("Not a prime no.")
                break
            else:
              print("Prime no.")

a = int(input("The value of a: "))
b = int(input("The value of b: "))

primeno(b)
primeno(a)
# Out:
# The value of a: 2
# The value of b: 2
# Prime no.
# Prime no.

# %%
def primeno(n):
    if n <= 1:
        print("Not a prime no.")
    else:
        if n == 2:
                print("Prime no.")
        for i in range(2, n):
            if (n % i == 0):
                print("Not a prime no.")
                break
            else:
              print("Prime no.")

a = int(input("The value of a: "))
b = int(input("The value of b: "))

primeno(b)
primeno(a)
# Out:
# The value of a: 2
# The value of b: 2
# Prime no.
# Prime no.

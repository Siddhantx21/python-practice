# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhantx21/python-practice/blob/main/for_%26_while_loop%20basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for k in range(2):
  print(k)
# Out:
# 0
# 1

# %%
for k in range(1,9):
  print(k)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for k in range(1,10,2):
  print(k)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
number=0
while(number<=40):
 number=int(input("Enter the value of number"))
 print(number)
number=number+1
print("out of the loop")
# Out:
# Enter the value of number1
# 1
# Enter the value of number41
# 41
# out of the loop

# %%
i=0
while(i<=10):
 i=int(input("Enter the value of number"))
 print(i)
 i=i+1
else:
  print("cond not satisfy")
# Out:
# Enter the value of number11
# 11
# cond not satisfy

# %%
Marks=0
while(Marks<100):
  Marks=int(input("Enter the value of marks:"))
  if(Marks<35):
    print("u failed",Marks)
  elif (Marks<=40):
    print("u barely passed",Marks)
  elif(Marks<=50):
    print("u passed",Marks)
  elif(Marks<=60):
    print("u passed with good marks",Marks)
  elif(Marks<=70):
    print("u passes with great marks",Marks)
  elif(Marks<=80):
    print("u passed with very great marks",Marks)
  elif(Marks<=90):
     print("u passed with excellent marks",Marks)
  elif(Marks<90 and Marks>100):
    print("u passed with very excellent marks",Marks)
  elif(Marks==100):
    print("u got full marks excellent kid",Marks)
# Out:
# u failed 34
# u barely passed 35
# u barely passed 40
# u passed 41
# u passed with good marks 51

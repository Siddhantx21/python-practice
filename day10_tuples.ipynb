# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhantx21/python-practice/blob/main/day10_tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tup=(1,3,45,True,"green")
print(type(tup),tup)
print(tup[0])
print(tup[-5])
if 2 in tup:
    print("2 is present")
else:
    print("2 is not present")
# Out:
# <class 'tuple'> (1, 3, 45, True, 'green')
# 1
# 1
# 2 is not present

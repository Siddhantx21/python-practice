# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhantx21/python-practice/blob/main/day8_function_arguments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def power(a,b=2):
  return(a**b)
a=int(input("enter the value of a:"))
power(a)
# Out:
# enter the value of a:4
# 16

# %%
def power(a,b=2):
  print("The square of following no is:",a**b)
a=int(input("enter the value of a:"))
power(a)
# Out:
# enter the value of a:3
# The square of following no is: 9

# %%
def Myself(a,b):
  return("My name is",a,"and I am",b,"years old")
a=input("Enter the name:")
b=int(input("Enter the age:"))
Myself(a,b)
# Out:
# Enter the name:sid
# Enter the age:12
# ('My name is', 'sid', 'and I am', 12, 'years old')

# %%
def sumofall(*arg):
  total=0
  for i in arg:
    total=total+i
  print(total)
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))
sumofall(a,b)
# Out:
# enter the value of a:123
# enter the value of b:12458
# 12581
